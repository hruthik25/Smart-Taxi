# %%
import gym
import numpy as np

# %%
env = gym.make("Taxi-v3")

# %%
state =env.reset()

# %%
state
# Out:
# 212

# %%
env.observation_space.n
# Out:
# 500

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# # Possible Actions
# down(0),up(1),right(2),left(3),pick-up(4),and drop-off(5)

# %%
n_states=env.observation_space.n
n_actions=env.action_space.n

# %%
n_actions
# Out:
# 6

# %%
n_states
# Out:
# 500

# %%
env.env.s =144

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.step(1)
# Out:
# (44, -1, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %%
env.env.s =44

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %%
env.step(4)
# Out:
# (44, -10, False, {'prob': 1.0})

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)

# %% [markdown]
# # how good does behaving completely random do?

# %%
state = env.reset()
counter = 0
g=0
reward = None

# %%
while reward !=20:
    state,reward,done,info =env.step(env.action_space.sample())
    counter +=1
    g+= reward

# %%
print("Solved in{} steps with a total reward of {}".format(counter,g))
# Out:
# Solved in1353 steps with a total reward of -5454

# %%
print("Solved in{} steps with a total reward of {}".format(counter,g))
# Out:
# Solved in1353 steps with a total reward of -5454

# %%
state =env.env.s =3
counter = 0
g=0
reward = None

# %%
while reward !=20:
    state,reward,done,info =env.step(env.action_space.sample())
    counter +=1
    g+= reward

# %%
print("Solved in{} steps with a total reward of {}".format(counter,g))
# Out:
# Solved in651 steps with a total reward of -2367

# %% [markdown]
# # one episode

# %%
Q =np.zeros([n_states,n_actions])

# %%
episode =1
G =0
alpha =0.618

# %%
for episode in range(1,1001):
    done = False
    G, reward = 0,0
    state = env.reset()
    while done != True:
            action = np.argmax(Q[state]) #1
            state2, reward, done, info = env.step(action) #2
            Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
            G += reward
            state = state2   
    if episode % 50 == 0:
        print('Episode {} Total Reward: {}'.format(episode,G))
# Out:
# Episode 50 Total Reward: -177
# Episode 100 Total Reward: -53
# Episode 150 Total Reward: 1
# Episode 200 Total Reward: 0
# Episode 250 Total Reward: -117
# Episode 300 Total Reward: 2
# Episode 350 Total Reward: 5
# Episode 400 Total Reward: 5
# Episode 450 Total Reward: 14
# Episode 500 Total Reward: 10
# Episode 550 Total Reward: 4
# Episode 600 Total Reward: 5
# Episode 650 Total Reward: 5
# Episode 700 Total Reward: 1
# Episode 750 Total Reward: 4
# Episode 800 Total Reward: 12
# Episode 850 Total Reward: 10
# Episode 900 Total Reward: 15
# Episode 950 Total Reward: 7
# Episode 1000 Total Reward: 8
